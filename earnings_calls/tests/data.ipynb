# %%
import pandas as pd
metadata_added = pd.read_csv("../earnings_calls_cleaned_metadata.csv")

# %%
metadata_added[metadata_added.Ticker == "AAPL"]
# Out:
#                                                     Text        Name  \
# 41033                                        Highlights:     Summary
# 41034                                      Revenue $58b.     Summary
# 41035  Near high-end of guidance range provided 90 da...     Summary
# 41036                                    Down 5% YoverY.     Summary
# 41037  Decline reflects 200 BP of negative FX due to ...     Summary
# ...                                                  ...         ...
# 47230  Although the companies may indicate and believ...  Disclaimer
# 47231  THE INFORMATION CONTAINED IN EVENT TRANSCRIPTS...  Disclaimer
# 47232                                             NO WAY  Disclaimer
# 47233  DOES THOMSON REUTERS OR THE APPLICABLE COMPANY...  Disclaimer
# 47234  USERS ARE ADVISED TO REVIEW THE APPLICABLE COM...  Disclaimer
#
#           Company    Position  Year Month  Date Ticker Section Quarter  \
# 41033     Summary         CFO  2019   Apr    30   AAPL    Mgmt      Q2
# 41034     Summary         CFO  2019   Apr    30   AAPL    Mgmt      Q2
# 41035     Summary         CFO  2019   Apr    30   AAPL    Mgmt      Q2
# 41036     Summary         CFO  2019   Apr    30   AAPL    Mgmt      Q2
# 41037     Summary         CFO  2019   Apr    30   AAPL    Mgmt      Q2
# ...           ...         ...   ...   ...   ...    ...     ...     ...
# 47230  Disclaimer  Disclaimer  2019   Jan    29   AAPL     Q/A      Q1
# 47231  Disclaimer  Disclaimer  2019   Jan    29   AAPL     Q/A      Q1
# 47232  Disclaimer  Disclaimer  2019   Jan    29   AAPL     Q/A      Q1
# 47233  Disclaimer  Disclaimer  2019   Jan    29   AAPL     Q/A      Q1
# 47234  Disclaimer  Disclaimer  2019   Jan    29   AAPL     Q/A      Q1
#
#       Participant_Type             File_Name  Sentence_id   QA_Flag
# 41033          Speaker  2019-Apr-30-AAPL.txt        41039    Answer
# 41034          Speaker  2019-Apr-30-AAPL.txt        41040    Answer
# 41035          Speaker  2019-Apr-30-AAPL.txt        41041    Answer
# 41036          Speaker  2019-Apr-30-AAPL.txt        41042    Answer
# 41037          Speaker  2019-Apr-30-AAPL.txt        41043    Answer
# ...                ...                   ...          ...       ...
# 47230          Analyst  2019-Jan-29-AAPL.txt        47236  Question
# 47231          Analyst  2019-Jan-29-AAPL.txt        47237  Question
# 47232          Analyst  2019-Jan-29-AAPL.txt        47238  Question
# 47233          Analyst  2019-Jan-29-AAPL.txt        47239  Question
# 47234          Analyst  2019-Jan-29-AAPL.txt        47240  Question
#
# [6202 rows x 14 columns]

# %%
metadata_added[metadata_added.Text == """I mean, I think the overall for me, across all of our product lines, whether it be Windows or whether it'd be Office 365 or Azure, developer momentum, ISV momentum is super important priority for us, both in terms of our developer evangelism, our product engineering teams, as well as everything that we will do to even create success for our partners, through our field sales organization is a top of mind priority."""]
# Out:
#                                                     Text           Name  \
# 39645  I mean, I think the overall for me, across all...  Satya Nadella
#
#                      Company Position  Year Month  Date Ticker Section  \
# 39645  Microsoft Corporation      CEO  2016   Apr    21   MSFT     Q/A
#
#       Quarter Participant_Type             File_Name  Sentence_id QA_Flag
# 39645      Q2          Speaker  2016-Apr-21-MSFT.txt        39651  Answer
